# %% [markdown]
# <a href="https://colab.research.google.com/github/Margo-by/neural-networks/blob/main/5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5 эпох, размер пакета 50, точность 93.07%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(800, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=50, epochs=5, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# ...
# 11490434/11490434 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 800)               628000
#
#  dense_1 (Dense)             (None, 10)                8010
#
# ...
# Total params: 636010 (2.43 MB)
# Trainable params: 636010 (2.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/5
# 960/960 - 6s - loss: 0.7459 - accuracy: 0.8204 - val_loss: 0.4047 - val_accuracy: 0.8944 - 6s/epoch - 6ms/step
# Epoch 2/5
# 960/960 - 6s - loss: 0.3827 - accuracy: 0.8970 - val_loss: 0.3248 - val_accuracy: 0.9133 - 6s/epoch - 7ms/step
# Epoch 3/5
# 960/960 - 5s - loss: 0.3252 - accuracy: 0.9107 - val_loss: 0.2904 - val_accuracy: 0.9202 - 5s/epoch - 6ms/step
# Epoch 4/5
# ...

# %%
#распечать
import h5py

# Функция для обработки каждого объекта в файле .h5
def print_weights(name, obj):
    if isinstance(obj, h5py.Dataset):
        print("  Вес:", name)
        print("  Значение:", obj[()])  # Получаем значения весов
    elif isinstance(obj, h5py.Group):
        print("Группа:", name)

# Открываем файл с весами модели
with h5py.File('mnist_model.h5', 'r') as f:
    # Печатаем ключи в файле
    print("Ключи в файле:", list(f.keys()))

    # Посещаем все объекты в файле и печатаем веса
    f.visititems(print_weights)

# %% [markdown]
# 125 эпох, размер пакета 100, точность 97.56%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(800, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=100, epochs=125, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_16 (Dense)            (None, 800)               628000
#
#  dense_17 (Dense)            (None, 10)                8010
#
# ...
# Total params: 636010 (2.43 MB)
# Trainable params: 636010 (2.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/125
# 480/480 - 9s - loss: 1.0016 - accuracy: 0.7682 - val_loss: 0.5430 - val_accuracy: 0.8760 - 9s/epoch - 20ms/step
# Epoch 2/125
# 480/480 - 5s - loss: 0.4917 - accuracy: 0.8785 - val_loss: 0.4043 - val_accuracy: 0.8975 - 5s/epoch - 11ms/step
# Epoch 3/125
# 480/480 - 4s - loss: 0.4023 - accuracy: 0.8940 - val_loss: 0.3536 - val_accuracy: 0.9053 - 4s/epoch - 9ms/step
# Epoch 4/125
# 480/480 - 4s - loss: 0.3596 - accuracy: 0.9021 - val_loss: 0.3235 - val_accuracy: 0.9133 - 4s/epoch - 9ms/step
# Epoch 5/125
# ...

# %% [markdown]
# #Выбираем лучшие гиперпараметры
#
# Создайте сеть с лучшими значениями всех гиперпараметров обучения, которые вы определили на предыдущем шаге. Увеличилась ли точность работы сети? Что можно сделать, чтобы еще больше увеличить точность?
#
# №1 Количество эпох обучения
# 125 эпох, размер пакета 100 - 97.56%(val_accuracy: 0.9748)
#
# 100 эпох (val_accuracy: 0.9724 )
#
# 75 эпох(val_accuracy: 0.9689)
#
# 50 эпох(val_accuracy: 0.9635)
#
# №2 Размер мини выборки
# При 50 - 97.35%
#
# При 100 - 97.37%
#
# При 200 - 94.89%
#
# При 400 - 93.56%
#
# По результатам эксперимента, при 50 эпохах, самая высокая точность при исподьзовании размера выборки 100.
#
# №3 нейроны на входном слое
# 1200 нейронов на входном слое(50 эпох,размер пакета 100) -Точность работы на тестовых данных: 96.65%
#
# 900-96.37%
#
# 700-96.20%
#
# 500-96.01%
#
# лучший результат показала сеть с 1200 нейронами:
#
# №4 скрытый слой
# 600 нейронов на скрытом слое 97.43%
#
# Будем добавлять скрытый слой на сеть с 1200 нейронами на входном слое, 100- размер пакета, 50 эпох.

# %% [markdown]
# #№1 Количество эпох обучения.
#
# Оценим влияние количества эпох обучения на качество обучения сети. Количество эпох задается в аргументе epochs метода model.fit:
#
# model.fit(X_train, Y_train, batch_size=200, epochs=XXX, validation_split=0.2, verbose=2)
#
# Попробуйте обучать сеть в течение 50, 75, 100 и 125 эпох. Выберите количество эпох, при котором самая высокая точность работы сети на тестовых данных.
#
#  125 эпох, размер пакета 100 - 97.56%(val_accuracy: 0.9748)
#
#  100 эпох (val_accuracy: 0.9724 )
#
#  75 эпох(val_accuracy: 0.9689)
#
#  50 эпох(val_accuracy: 0.9635)
#
# по результатам эксперимента при 125 эпохах получаем лучший результат, но он уже довольно близок к переобучению.

# %% [markdown]
# Размер мини-выборки. Оценим влияние размера мини-выборки на качество обучения сети. Размер задается в аргументе batch_size метода model.fit:
#
#  model.fit(X_train, Y_train, batch_size=XXX, epochs=100, validation_split=0.2, verbose=2)
#
# Используйте размер мини-выборки 50, 100, 200 и 400. Выберите значение, при котором самая высокая точность работы сети на тестовых данных.

# %% [markdown]
# 50 эпох, размер пакета 50
#
# Точность работы на тестовых данных: 97.35%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(800, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=50, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 800)               628000
#
#  dense_5 (Dense)             (None, 10)                8010
#
# ...
# Total params: 636010 (2.43 MB)
# Trainable params: 636010 (2.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 960/960 - 8s - loss: 0.7422 - accuracy: 0.8246 - val_loss: 0.4023 - val_accuracy: 0.8981 - 8s/epoch - 8ms/step
# Epoch 2/50
# 960/960 - 7s - loss: 0.3816 - accuracy: 0.8977 - val_loss: 0.3237 - val_accuracy: 0.9119 - 7s/epoch - 8ms/step
# Epoch 3/50
# 960/960 - 8s - loss: 0.3254 - accuracy: 0.9103 - val_loss: 0.2915 - val_accuracy: 0.9200 - 8s/epoch - 8ms/step
# Epoch 4/50
# 960/960 - 6s - loss: 0.2945 - accuracy: 0.9179 - val_loss: 0.2699 - val_accuracy: 0.9255 - 6s/epoch - 7ms/step
# Epoch 5/50
# ...

# %% [markdown]
# 50 эпох, размер пакета 100 97.37%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(800, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=50, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 800)               628000
#
#  dense_7 (Dense)             (None, 10)                8010
#
# ...
# Total params: 636010 (2.43 MB)
# Trainable params: 636010 (2.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 960/960 - 7s - loss: 0.7590 - accuracy: 0.8173 - val_loss: 0.4058 - val_accuracy: 0.8947 - 7s/epoch - 7ms/step
# Epoch 2/50
# 960/960 - 6s - loss: 0.3837 - accuracy: 0.8973 - val_loss: 0.3233 - val_accuracy: 0.9133 - 6s/epoch - 7ms/step
# Epoch 3/50
# 960/960 - 8s - loss: 0.3244 - accuracy: 0.9110 - val_loss: 0.2895 - val_accuracy: 0.9202 - 8s/epoch - 8ms/step
# Epoch 4/50
# 960/960 - 6s - loss: 0.2922 - accuracy: 0.9192 - val_loss: 0.2653 - val_accuracy: 0.9269 - 6s/epoch - 6ms/step
# Epoch 5/50
# ...

# %% [markdown]
# 50 эпох, размер пакета 200, 94.89%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(800, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=200, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 800)               628000
#
#  dense_11 (Dense)            (None, 10)                8010
#
# ...
# Total params: 636010 (2.43 MB)
# Trainable params: 636010 (2.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 240/240 - 4s - loss: 1.2913 - accuracy: 0.7019 - val_loss: 0.7759 - val_accuracy: 0.8453 - 4s/epoch - 18ms/step
# Epoch 2/50
# 240/240 - 4s - loss: 0.6681 - accuracy: 0.8512 - val_loss: 0.5391 - val_accuracy: 0.8733 - 4s/epoch - 15ms/step
# Epoch 3/50
# 240/240 - 5s - loss: 0.5210 - accuracy: 0.8740 - val_loss: 0.4508 - val_accuracy: 0.8880 - 5s/epoch - 19ms/step
# Epoch 4/50
# 240/240 - 4s - loss: 0.4537 - accuracy: 0.8850 - val_loss: 0.4036 - val_accuracy: 0.8960 - 4s/epoch - 15ms/step
# Epoch 5/50
# ...

# %% [markdown]
# 50 эпох, размер пакета 400, 93.56%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(800, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=400, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 800)               628000
#
#  dense_13 (Dense)            (None, 10)                8010
#
# ...
# Total params: 636010 (2.43 MB)
# Trainable params: 636010 (2.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 120/120 - 4s - loss: 1.6913 - accuracy: 0.5593 - val_loss: 1.1819 - val_accuracy: 0.7777 - 4s/epoch - 31ms/step
# Epoch 2/50
# 120/120 - 3s - loss: 0.9899 - accuracy: 0.8020 - val_loss: 0.7907 - val_accuracy: 0.8433 - 3s/epoch - 27ms/step
# Epoch 3/50
# 120/120 - 4s - loss: 0.7371 - accuracy: 0.8406 - val_loss: 0.6257 - val_accuracy: 0.8655 - 4s/epoch - 31ms/step
# Epoch 4/50
# 120/120 - 4s - loss: 0.6159 - accuracy: 0.8595 - val_loss: 0.5379 - val_accuracy: 0.8775 - 4s/epoch - 32ms/step
# Epoch 5/50
# ...

# %% [markdown]
#   №2 Размер мини-выборки. Оценим влияние размера мини-выборки на качество обучения сети. Размер задается в аргументе batch_size метода model.fit:
#
#   model.fit(X_train, Y_train, batch_size=XXX, epochs=100, validation_split=0.2, verbose=2)
#
#   Используйте размер мини-выборки 50, 100, 200 и 400. Выберите значение, при котором самая высокая точность работы сети на тестовых данных.
#
#
#   При 50 - 97.35%
#
#   При 100 - 97.37%
#
#   При 200 - 94.89%
#
#   При 400 - 93.56%
#
#   По результатам эксперимента, при 50 эпохах, самая высокая точность при исподьзовании размера выборки 100.

# %% [markdown]
#  №3 Количество нейронов входного слоя. Изменяйте количество нейронов во входном слое и оцените, как оно влияет на качество обучения сети. Количество нейронов задается при создании входного слоя:
#
#  model.add(Dense(XXX, input_dim=784, activation="relu", kernel_initializer="normal"))
#
# Используйте значения 500, 700, 900, 1200. Выберите значение, при котором самая высокая точность работы сети на тестовых данных.
#
# Будем тестировать при 50 эпохах и размере выборки 100

# %% [markdown]
# 500 нейронов 96.01%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(500, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=100, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_20 (Dense)            (None, 500)               392500
#
#  dense_21 (Dense)            (None, 10)                5010
#
# ...
# Total params: 397510 (1.52 MB)
# Trainable params: 397510 (1.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 480/480 - 4s - loss: 1.1764 - accuracy: 0.7344 - val_loss: 0.6331 - val_accuracy: 0.8643 - 4s/epoch - 8ms/step
# Epoch 2/50
# 480/480 - 5s - loss: 0.5539 - accuracy: 0.8669 - val_loss: 0.4432 - val_accuracy: 0.8894 - 5s/epoch - 10ms/step
# Epoch 3/50
# 480/480 - 4s - loss: 0.4393 - accuracy: 0.8858 - val_loss: 0.3785 - val_accuracy: 0.9030 - 4s/epoch - 8ms/step
# Epoch 4/50
# 480/480 - 3s - loss: 0.3887 - accuracy: 0.8958 - val_loss: 0.3450 - val_accuracy: 0.9073 - 3s/epoch - 6ms/step
# Epoch 5/50
# ...

# %% [markdown]
# 700 нейронов 96.20%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(700, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=100, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_22 (Dense)            (None, 700)               549500
#
#  dense_23 (Dense)            (None, 10)                7010
#
# ...
# Total params: 556510 (2.12 MB)
# Trainable params: 556510 (2.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 480/480 - 5s - loss: 1.0441 - accuracy: 0.7624 - val_loss: 0.5567 - val_accuracy: 0.8763 - 5s/epoch - 11ms/step
# Epoch 2/50
# 480/480 - 4s - loss: 0.5015 - accuracy: 0.8767 - val_loss: 0.4085 - val_accuracy: 0.8974 - 4s/epoch - 8ms/step
# Epoch 3/50
# 480/480 - 4s - loss: 0.4078 - accuracy: 0.8919 - val_loss: 0.3546 - val_accuracy: 0.9070 - 4s/epoch - 8ms/step
# Epoch 4/50
# 480/480 - 5s - loss: 0.3642 - accuracy: 0.9008 - val_loss: 0.3250 - val_accuracy: 0.9136 - 5s/epoch - 10ms/step
# Epoch 5/50
# ...

# %% [markdown]
# 900 нейронов  96.37%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(900, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=100, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 900)               706500
#
#  dense_25 (Dense)            (None, 10)                9010
#
# ...
# Total params: 715510 (2.73 MB)
# Trainable params: 715510 (2.73 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 480/480 - 6s - loss: 0.9792 - accuracy: 0.7705 - val_loss: 0.5240 - val_accuracy: 0.8795 - 6s/epoch - 13ms/step
# Epoch 2/50
# 480/480 - 5s - loss: 0.4778 - accuracy: 0.8809 - val_loss: 0.3937 - val_accuracy: 0.8999 - 5s/epoch - 10ms/step
# Epoch 3/50
# 480/480 - 5s - loss: 0.3933 - accuracy: 0.8961 - val_loss: 0.3450 - val_accuracy: 0.9071 - 5s/epoch - 10ms/step
# Epoch 4/50
# 480/480 - 6s - loss: 0.3524 - accuracy: 0.9041 - val_loss: 0.3166 - val_accuracy: 0.9150 - 6s/epoch - 12ms/step
# Epoch 5/50
# ...

# %% [markdown]
# 1200 нейронов 96.65%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(1200, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=100, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_26 (Dense)            (None, 1200)              942000
#
#  dense_27 (Dense)            (None, 10)                12010
#
# ...
# Total params: 954010 (3.64 MB)
# Trainable params: 954010 (3.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 480/480 - 7s - loss: 0.8694 - accuracy: 0.7927 - val_loss: 0.4756 - val_accuracy: 0.8855 - 7s/epoch - 15ms/step
# Epoch 2/50
# 480/480 - 6s - loss: 0.4452 - accuracy: 0.8857 - val_loss: 0.3680 - val_accuracy: 0.9043 - 6s/epoch - 12ms/step
# Epoch 3/50
# 480/480 - 7s - loss: 0.3715 - accuracy: 0.9005 - val_loss: 0.3252 - val_accuracy: 0.9115 - 7s/epoch - 14ms/step
# Epoch 4/50
# 480/480 - 6s - loss: 0.3343 - accuracy: 0.9082 - val_loss: 0.3008 - val_accuracy: 0.9183 - 6s/epoch - 13ms/step
# Epoch 5/50
# ...

# %% [markdown]
# #№3 результаты
#
# 1200 нейронов на входном слое(50 эпох,размер пакета 100) -Точность работы на тестовых данных: 96.65%
#
# 900-96.37%
#
# 700-96.20%
#
# 500-96.01%
#
# лучший результат показала сеть с 1200 нейронами:

# %% [markdown]
# #№4
#
# Добавляем скрытый слой. Добавим в нашу сеть скрытый слой, чтобы она стала глубокой:
#
#  model.add(Dense(800, input_dim=784, activation="relu", kernel_initializer="normal"))
#
#  model.add(Dense(600, activation="relu", kernel_initializer="normal"))
#
#  model.add(Dense(10, activation="softmax", kernel_initializer="normal"))
#
# Попробуйте добавить скрытый слой с разным количеством нейронов: 500, 700, 900 и 1200. Выберите наиболее подходящее количество нейронов скрытого слоя.
#
# Оцените, как изменяется время обучения, при добавлении скрытого слоя с разным количеством нейронов.
#
# Будем добавлять скрытый слой на сеть с 1200 нейронами на входном слое, 100- размер пакета, 50 эпох.

# %% [markdown]
# 600 нейронов на скрытом слое 97.43%
#
# Будем добавлять скрытый слой на сеть с 1200 нейронами на входном слое, 100- размер пакета, 50 эпох.

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(1200, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(600, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=100, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_31 (Dense)            (None, 1200)              942000
#
#  dense_32 (Dense)            (None, 600)               720600
#
#  dense_33 (Dense)            (None, 10)                6010
#
# ...
# Total params: 1668610 (6.37 MB)
# Trainable params: 1668610 (6.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 480/480 - 13s - loss: 0.7976 - accuracy: 0.8080 - val_loss: 0.4028 - val_accuracy: 0.8992 - 13s/epoch - 27ms/step
# Epoch 2/50
# 480/480 - 12s - loss: 0.3728 - accuracy: 0.8996 - val_loss: 0.3090 - val_accuracy: 0.9147 - 12s/epoch - 25ms/step
# Epoch 3/50
# 480/480 - 12s - loss: 0.3072 - accuracy: 0.9146 - val_loss: 0.2741 - val_accuracy: 0.9247 - 12s/epoch - 25ms/step
# Epoch 4/50
# ...

# %% [markdown]
# 1200 нейронов на скрытом слое

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# Устанавливаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Преобразование размерности изображений
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
# Нормализация данных
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, 10)
Y_test = to_categorical(y_test, 10)

# Создаем последовательную модель
model = Sequential()

# Добавляем уровни сети
model.add(Dense(1200, input_dim=784, activation="relu", kernel_initializer="normal"))
model.add(Dense(1200, activation="relu", kernel_initializer="normal"))
model.add(Dense(10, activation="softmax", kernel_initializer="normal"))

# Компилируем модель
model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())

# Обучаем сеть
model.fit(X_train, Y_train, batch_size=100, epochs=50, validation_split=0.2, verbose=2)

# Оцениваем качество обучения сети на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))

# Генерируем описание модели в формате json
model_json = model.to_json()
# Записываем модель в файл
json_file = open("mnist_model.json", "w")
json_file.write(model_json)
json_file.close()

model.save_weights("mnist_model.h5")

print ("Сохранили Model")
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_34 (Dense)            (None, 1200)              942000
#
#  dense_35 (Dense)            (None, 1200)              1441200
#
#  dense_36 (Dense)            (None, 10)                12010
#
# ...
# Total params: 2395210 (9.14 MB)
# Trainable params: 2395210 (9.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 480/480 - 19s - loss: 0.6505 - accuracy: 0.8364 - val_loss: 0.3497 - val_accuracy: 0.9075 - 19s/epoch - 39ms/step
# Epoch 2/50
# 480/480 - 18s - loss: 0.3256 - accuracy: 0.9112 - val_loss: 0.2772 - val_accuracy: 0.9241 - 18s/epoch - 38ms/step
# Epoch 3/50
# 480/480 - 19s - loss: 0.2710 - accuracy: 0.9251 - val_loss: 0.2433 - val_accuracy: 0.9330 - 19s/epoch - 40ms/step
# Epoch 4/50
# ...
